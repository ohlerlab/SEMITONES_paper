# %% [markdown]
# ### Set up the notebook

# %%
import pickle
import numpy as np
import networkx as nx
import netwulf
import pandas as pd

# %% [markdown]
# ### Load the data

# %%
annotations = ["HSC", "MPP", "CMP",
               "MEP", "ERYTHROCYTE",
               "GMP", "GP", "BASO",
               "MP", "MONO_CLAS", "MONO_INT", "MONO_NONCLAS", "MDSC",
               "CLP", "PRE_B", "B_TRANSITIONAL", "B_NAIVE", "B_MEMORY", "PLASMA",
               "CD4_NAIVE", "CD4_MEMORY", "CD4_TH17", "T_REG", "CD4_TERM_EFFECT",
               "CD8_NAIVE", "CD8_CENTRAL_MEMORY", "CD8_EFFECTOR_MEMORY", "CD8_MAIT", "CD8_TERM_EFFECT",
               "NK", "mDC", "pDC"]

# %%
with open("greenleaf_scRNA_geneset_graphs_interaction.pkl", "rb") as f:
    MST = pickle.load(f)
f.close()

# %%
idx_annot = dict(zip(annotations, MST.keys()))

# %%
idx_annot
# Out:
# {'HSC': '13820',
#  'MPP': '16578',
#  'CMP': '15806',
#  'MEP': '18416',
#  'ERYTHROCYTE': '5577',
#  'GMP': '13295',
#  'GP': '4672',
#  'BASO': '15070',
#  'MP': '2940',
#  'MONO_CLAS': '26333',
#  'MONO_INT': '30019',
#  'MONO_NONCLAS': '21476',
#  'MDSC': '3447',
#  'CLP': '19106',
#  'PRE_B': '6116',
#  'B_TRANSITIONAL': '7284',
#  'B_NAIVE': '11487',
#  'B_MEMORY': '282',
#  'PLASMA': '31097',
#  'CD4_NAIVE': '27644',
#  'CD4_MEMORY': '11793',
#  'CD4_TH17': '9687',
#  'T_REG': '29149',
#  'CD4_TERM_EFFECT': '32206',
#  'CD8_NAIVE': '28213',
#  'CD8_CENTRAL_MEMORY': '8560',
#  'CD8_EFFECTOR_MEMORY': '6126',
#  'CD8_MAIT': '26382',
#  'CD8_TERM_EFFECT': '8089',
#  'NK': '30460',
#  'mDC': '25197',
#  'pDC': '2680'}

# %% [markdown]
# ### Figure 3a

# %%
k = idx_annot["CD8_NAIVE"]
network1, config = netwulf.visualize(MST[k], port=9854)

# %%
from matplotlib import pyplot as plt
ha = "left"
labelcol = "#100101"
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network1, fig=fig, ax=ax)
netwulf.add_node_label(ax, network1, "CD8A", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "CD8B", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "CD3E", fontsize=7, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "CD3D", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "CD3G", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "LCK", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "NELL2", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "KLF2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "EEF1A1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "FAU", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "LEF1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "LEPROTL1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "KLF2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "EEF1B2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "LDHB", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network1, "RGS10", fontsize=4, ha=ha, color=labelcol)
plt.tight_layout()
fig.savefig("CD8_naive_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/CD8_naive_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure 3b

# %%
k = idx_annot["CD4_TH17"]
network, config3 = netwulf.visualize(MST[k], port=9854)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network, fig=fig, ax=ax)
netwulf.add_node_label(ax, network, "LTB", fontsize=7, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "TNFRSF4", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "S100A4", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "B2M", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "CD3E", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "EVL", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "CCR10", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "CRIP1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "S100A10", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "CD52", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "LCK", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "JUNB", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "AQP3", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "ITGB1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "LMNA", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "IL32", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "KLF2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "HLA-A", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "IL7R", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network, "CD2", fontsize=4, ha=ha, color=labelcol)
plt.tight_layout()
fig.savefig("Th17_naive_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/Th17_naive_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure S9

# %%
k = idx_annot["B_TRANSITIONAL"]
network_btrans, config_btrans = netwulf.visualize(MST[k], port=9854)

# %%
labelcol = "#100101"
ha="left"
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network_btrans, fig=fig, ax=ax)
netwulf.add_node_label(ax, network_btrans, "IGLL5", fontsize=7, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "CD79B", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "PCDH9", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "CD81", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "DTX1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "FAM129C", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "YBX3", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "HLA-DRA", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "BTG1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "HIST1H1C", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "TCL1A", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "MZB1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "MYL4", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "RGS2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "JUND", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "SOX4", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "CXCR4", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "H1FX", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "PPP1R14A", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "PTMA", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "LHPP", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "IRF4", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_btrans, "FCRLA", fontsize=4, ha=ha, color=labelcol)

plt.tight_layout()
fig.savefig("B_transitional_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/B_transitional_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure S8 left panel

# %%
k = idx_annot["MDSC"]
network_mdsc, config_mdsc = netwulf.visualize(MST[k], port=9854)

# %%
labelcol = "#100101"
ha="left"
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network_mdsc, fig=fig, ax=ax)
netwulf.add_node_label(ax, network_mdsc, "S100A12", fontsize=7, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "S100A6", fontsize=7, ha=ha, color=labelcol)
#
netwulf.add_node_label(ax, network_mdsc, "S100A8", fontsize=6, ha=ha, color=labelcol)
#
netwulf.add_node_label(ax, network_mdsc, "BLVRB", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "ACTB", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "RGS2", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "SRGN", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "FTL", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "CYBA", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "LYZ", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "S100A9", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "TYROBP", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "ALOX5AP", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "PADI4", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "NCF1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_mdsc, "FCN1", fontsize=5, ha=ha, color=labelcol)

plt.tight_layout()
fig.savefig("MDSC_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/MDSC_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure S8 middle panel

# %%
k = idx_annot["MONO_CLAS"]
network_clas, config_clas = netwulf.visualize(MST[k], port=9854)

# %%
labelcol = "#100101"
ha="left"
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network_clas, fig=fig, ax=ax)
netwulf.add_node_label(ax, network_clas, "S100A9", fontsize=7, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_clas, "S100A6", fontsize=6, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_clas, "RGS2", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "VCAN", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "NEAT1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "AIF1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "TGFBI", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "TYMP", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "S100A10", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "ALDH1A1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "SH3BGRL3", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "COTL1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "LYZ", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "DUSP1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "LAPTM5", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "S100A8", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "S100A12", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "ITGB2", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "CD14", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "SRGN", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "CTSZ", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "FCN1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "TYROBP", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "BLVRB", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "FCER1G", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "CTSS", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "FTH1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "CFD", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "FTL", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_clas, "MNDA", fontsize=4, ha=ha, color=labelcol)


plt.tight_layout()
fig.savefig("Classical_monocyte_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/Classical_monocyte_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure S8 right panel

# %%
k = idx_annot["MONO_INT"]
network_int, config_int = netwulf.visualize(MST[k], port=9854)

# %%
labelcol = "#100101"
ha="left"
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network_int, fig=fig, ax=ax)
netwulf.add_node_label(ax, network_int, "LGALS2", fontsize=7, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_int, "CTSS", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "S100A10", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "S100A6", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "FTL", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "AIF1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "TYROBP", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "RGS2", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "HLA-DRB1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "NEAT1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "HLA-DRA", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "CST3", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "COTL1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "FTH1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "S100A10", fontsize=5, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_int, "S100A4", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "SAT1", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "CTSZ", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "FGL2", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "TYMP", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "S100A9", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "CFD", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "SH3BGRL3", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "LYZ", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "TGFBI", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "BLVRB", fontsize=4, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_int, "FCER1G", fontsize=4, ha=ha, color=labelcol)


plt.tight_layout()
fig.savefig("Intermediate_monocyte_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/Intermediate_monocyte_interaction_network.png", dpi=300)

# %% [markdown]
# ### Figure S9a (top left)

# %%
k = idx_annot["ERYTHROCYTE"]
network_ery, config_ery = netwulf.visualize(MST[k], port=9854)

# %%
labelcol = "#100101"
ha="left"
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(5, 5), dpi=300)
ax = fig.gca()
netwulf.draw_netwulf(network_ery, fig=fig, ax=ax)
netwulf.add_node_label(ax, network_ery, "HBB", fontsize=7, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_ery, "AHSP", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "GFI1B", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "HBD", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "BLVRB", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "SPTA1", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "HES6", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "MYL4", fontsize=6, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "SYNGR1", fontsize=6, ha=ha, color=labelcol)

netwulf.add_node_label(ax, network_ery, "HSPD1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "LMNA", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "TMEM56", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "HSP90AA1", fontsize=5, ha=ha, color=labelcol)
netwulf.add_node_label(ax, network_ery, "AKR1C3", fontsize=5, ha=ha, color=labelcol)

plt.tight_layout()
fig.savefig("Erythrocyte_interaction_network.png", dpi=300)
fig.savefig("../../../../Desktop/Figs/Erythrocyte_interaction_network.png", dpi=300)
